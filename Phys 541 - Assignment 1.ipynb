# %% [markdown]
# ## Phys 541 Assignment 1 Due Jan. 18, 2024
#
# ### Hasti Hojabrosadati

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### **Problem 1 Part c
# Calculate and plot the specific heat for N such atoms along with the classical result from Qu. 1 on
# the same graph. Use 0 ≤ kB/hw ≤ 3 on the horizontal axis, and 0 ≤ C=(NkB) ≤ 4 on the vertical
# axis. What are the limits for the specific heat as T ! 0 and T ! 1?

# %%
# x = K_BT/ℏw = 1/βℏw
### C_cl = 3NK_B  --> Ycl = C_cl/NK_B=3

plt.axhline(y = 3, color = 'r', linestyle = '-') 

x= np.linspace(0,3,100,endpoint=True)
y_qu = 3*(1/x)**2 *np.exp(1/x)/( np.exp(1/x)-1)**2
plt.plot(x,y_qu)
# Out:
# C:\Users\Milo\AppData\Local\Temp\ipykernel_10800\4156664874.py:6: RuntimeWarning: divide by zero encountered in divide
#   y_qu = 3*(1/x)**2 *np.exp(1/x)/( np.exp(1/x)-1)**2
# C:\Users\Milo\AppData\Local\Temp\ipykernel_10800\4156664874.py:6: RuntimeWarning: invalid value encountered in divide
#   y_qu = 3*(1/x)**2 *np.exp(1/x)/( np.exp(1/x)-1)**2
